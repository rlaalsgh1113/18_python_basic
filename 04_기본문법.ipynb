# %%
# 세미콜론
print("Hello world");
# Out:
# Hello world

# %%
print("Hello"); print("1234")
# Out:
# Hello
# 1234

# %%
# 한 줄 주석
# 출력하기
print("Hello world")

# %%
# 블록 주석
# ctrl + /
print("Hello world")
print("Hello world")
print("Hello world")

# %%
# 들여쓰기

a = 5
if a == 10 :
    print("10입니다")
else :
    print("틀림")
# Out:
# 틀림
