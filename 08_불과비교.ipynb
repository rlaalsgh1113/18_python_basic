# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# 비교 연산자
3 > 1
# Out:
# True

# %%
# 숫자가 같은지 다른지 비교
print(10 == 10)
print(10 != 10)
# Out:
# True
# False

# %%
print("Python" == "Python")
print("Python" == "python") # 대소문자 구분함
# Out:
# True
# False

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0) 주소가 같은지 확인 ( 잘 안씀 )
print(id(1))
print(id(1.0))
# Out:
# True
# 140714734838904
# 2715241229648

# %%
# 논리 연산자 사용하기

print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True
# Out:
# False

# %%
(not True) and False or not False  # = False and False or True
# Out:
# True

# %%
# 논리 연산자와 비교 연산자 함께 사용하기

print(10 == 10 and 10 != 5)
print(10 > 5 or 10 < 3)
print(not (10 > 5))
print(not 10)
print(False > 5)

print(not 1 is 1.0)
# Out:
# True
# True
# False
# False
# False
# True
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS38\AppData\Local\Temp\ipykernel_8048\368729181.py:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
# 연습문제 8.4
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >= 50 and english >= 50 and mathematics >= 50 and science >= 50)
# Out:
# False

# %%
# 심사문제 8.5
korean, english, mathematics, science = map(int, input().split())
print(korean >= 90 and english > 80 and mathematics > 85 and science >= 80)
# Out:
# False
