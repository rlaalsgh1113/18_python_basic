# %%
# 변수 만들기
x = 10

## 1. 영문 문자와 숫자 사용 가능
## 2. 대소문자 구분
## 3. 문자부터 시작해야 함
## 4. __(밑줄 문자)로 시작 가능
## 5. 특수 문자(+,-,*,/, $, @, % 등) 사용 불가
## 6. 파이썬 키워드(for, if, while, and, or) 변수 사용 불가

# %%
x = 10
print(x)
# Out:
# 10

# %%
print = 100
print
# Out:
# 100

# %%
print("hello world")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("hello world")
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print("hello world")
# Out:
# hello world

# %%
hello_world = "hi" # snake case
hello_World = "hi" # camel case
HelloWorld = "hi" # pascal case

# %%
# 변수의 자료형 알아내기
x = 10
type(x)
# Out:
# int

# %%
y = "hello, world"
type(y)
# Out:
# str

# %%
# 변수 여러 개를 한번에 만들기
x, y, z = 10, 20, 30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x, y, z = 10, 20
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x, y, z = 10, 20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x = y = z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x, y = 10, 20
x, y = y,  x
print(x)
print(y)
# Out:
# 20
# 10

# %%
# 변수로 계산하기
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
a = 10
print(a + 20)
print(a)
# Out:
# 30
# 10

# %%
a = a + 20
print(a)
# Out:
# 30

# %%
a = 10
a += 20
print(a)
# Out:
# 30
