# %%
# 사칙연산
1 + 1
# Out:
# 2

# %%
1 - 2
# Out:
# -1

# %%
5 / 2
# Out:
# 2.5

# %%
# 소수점 이하를 버리는 연산자 // (몫)
print(5 // 2)
print(4 // 2)
# Out:
# 2
# 2

# %%
# 나머지를 구하는 연산자 %
5 % 2
7 % 4
# Out:
# 3

# %%
# 거듭제곱을 구하는 연산자 **
2 ** 10
# Out:
# 1024

# %%
# 값을 정수로 만들기
int(5.5)
int(5 / 2)
int("12")
# Out:
# 12

# %%
# 객체의 자료형 알아내기
a = 10
type(a)
type("1")
# Out:
# str

# %%
# 실수 계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
# 실수와 정수를 함께 계산하면?

4.2 + 5
# Out:
# 9.2

# %%
# 값을 실수로 만들기

print(float(5))
# Out:
# 5.0

# %%
# 괄호 사용하기
(35 + 1) * 2
# Out:
# 72

# %%
a = 0.2467 * 12 + 4.159
print(int(a))
# Out:
# 7

# %%
AP = 102
print(AP * 0.6 + 225)
# Out:
# 286.2
