# %%
# 심사문제 24.5

a = input().split(" ")

b = a.count("the")

print(b)
# Out:
# 3

# %%
# 심사문제 24.6

price = map(int, input().split(";"))
a = list(price)
b = sorted(a, reverse=True)
for i in b :
    print(f"{i : 9,}")
# Out:
#  1,285,000
#   367,500
#   250,000
#   158,000
#    83,000
#    59,200
#    51,900
