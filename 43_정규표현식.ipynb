# %%
# 문자열 판단하기

import re

re.match("Hello", "Hello, world!")
re.match("Python", "Hello, world!") # 없어서 출력 x

# %%
# 문자열이 맨 앞에 오는지 맨 뒤에 오는지 판단하기

# ^문자열 - 문자열로 시작할때
# 문자열$ - 문자열로 끝날때
# re.search("패턴", "문자열")

re.search("^Hello", "Hello, World!")
re.search("World!$", "Hello, World!")
# Out:
# <re.Match object; span=(7, 13), match='World!'>

# %%
# 지정된 문자열이 하나라도 포함되는지 판단하기

re.match("Hello|world", "Hello")
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %%
# 범위 판단하기
# (*) 0개 이상 (+) 한개 이상
# [0-9]*
# [0-9]+

print(re.match("[0-9]*","1234"))
print(re.match("[0-9]+","1234"))
print(re.match("[0-9]+","abcd"))
# Out:
# <re.Match object; span=(0, 4), match='1234'>
# <re.Match object; span=(0, 4), match='1234'>
# None

# %%
print(re.match("a*b","b"))
print(re.match("a+b","b"))
print(re.match("a*b","aab"))
print(re.match("a+b","aab"))
# Out:
# <re.Match object; span=(0, 1), match='b'>
# None
# <re.Match object; span=(0, 3), match='aab'>
# <re.Match object; span=(0, 3), match='aab'>

# %%
# 문자가 한 개만 있는지 판단하기
# ?  0개인지 1개인지 판단
# [0-9]?

print(re.match("abc?d", "abd"))
print(re.match("abc?d", "abcd"))
print(re.match("abc?d", "abccccd"))
print(re.match("ab[0-9]?c","ab3c"))
print(re.match("ab.d", "abxd")) # . = .이 있는 위치에 문자나 숫자가 한개 있는지 판단
# Out:
# <re.Match object; span=(0, 3), match='abd'>
# <re.Match object; span=(0, 4), match='abcd'>
# None
# <re.Match object; span=(0, 4), match='ab3c'>
# <re.Match object; span=(0, 4), match='abxd'>

# %%
# 문자개수 판단하기
# 문자{개수}
# (문자열){개수}

print(re.match("h{3}", "hhhelllo"))
print(re.match("h{3}", "hhhhelllo"))
print(re.match("hello{3}", "hellohellohelloworld"))
print(re.match("(hello){3}", "hellohellohelloworld"))
# Out:
# <re.Match object; span=(0, 3), match='hhh'>
# <re.Match object; span=(0, 3), match='hhh'>
# None
# <re.Match object; span=(0, 15), match='hellohellohello'>

# %%
print(re.match("[0-9]{3}-[0-9]{4}-[0-9]{4}", "010-1234-1234"))
print(re.match("[0-9]{3}-[0-9]{4}-[0-9]{4}", "010-1234-123"))
# Out:
# <re.Match object; span=(0, 13), match='010-1234-1234'>
# None

# %%
# (문자){시작개수, 끝개수}
# (문자1){시작개수, 끝개수}
#[0-9]{시작개수, 끝개수}

print(re.match("[0-9]{2,3}-[0-9]{3,4}-[0-9]{4}", "02-123-1234"))
print(re.match("[0-9]{2,3}-[0-9]{3,4}-[0-9]{4}", "010-1234-1234"))
print(re.match("[0-9]{2,3}-[0-9]{3,4}-[0-9]{4}", "02-34-1234"))
# Out:
# <re.Match object; span=(0, 11), match='02-123-1234'>
# <re.Match object; span=(0, 13), match='010-1234-1234'>
# None

# %%
# 숫자와 영문 문자 조합해서 판단하기

# a-z
# A-Z

print(re.match("[a-zA-Z0-9]+", "Hello1234"))
print(re.match("[A-Z0-9]+", "hello1234"))
# Out:
# <re.Match object; span=(0, 9), match='Hello1234'>
# None

# %%
# 가-힣

print(re.match("[가-힣]+", "홍길동"))
# Out:
# <re.Match object; span=(0, 3), match='홍길동'>

# %%
# 특정 문자 범위에 포함되지 않는지 판단하기
# [^범위] # 대괄호 안 ^는 이 범위가 아닌것을 찾음
# [^범위]+ 

print(re.match("[^A-Z]+", "Hello"))
print(re.match("[^A-Z]+", "hello"))
# Out:
# None
# <re.Match object; span=(0, 5), match='hello'>

# %%
# ^[범위]   
# ^[범위]+

print(re.search("^[A-Z]+", "Hello"))
# Out:
# <re.Match object; span=(0, 1), match='H'>
