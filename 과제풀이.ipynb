# %%
a = "hello world"
print(list(a))

b = 1
c = "1"
print(type(b))
print(type(c))
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']
# <class 'int'>
# <class 'str'>

# %%
a = "a, b, c, d, e"
print(a.split(","))

b = ["Python", "is", "fun"]
print(" ".join(b))
# Out:
# ['a', ' b', ' c', ' d', ' e']
# Python is fun

# %%
list1 = []
list1.append(10)
list1.append(20)
list1.append(30)
print(list1)

list1.insert(1, 15)
list1.insert(0, 5)
print(list1)

list1.extend([40, 50])
print(list1)
# Out:
# [10, 20, 30]
# [5, 10, 15, 20, 30]
# [5, 10, 15, 20, 30, 40, 50]

# %%
items = ["a", "b", "c", "b", "d", "b", "e"]
items.remove("b")
print(items)
items.pop()
print(items)
items.pop(0)
print(items)
items.clear()
print(items)
# Out:
# ['a', 'c', 'b', 'd', 'b', 'e']
# ['a', 'c', 'b', 'd', 'b']
# ['c', 'b', 'd', 'b']
# []

# %%
data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
print(data.index(5))
print(data.count(5))
print(data.count(1))
# Out:
# 4
# 3
# 2

# %%
t1 = (1, 2, 3, 4, 5)
t2 = ("red", "green", "blue")
t3 = (10,)
t4_1 = ()  
t4_2 = tuple()   
t5 = 4, 5, 6

# %%
fruits = {
    'apple': 1000,
    'banana': 1500,
    'orange': 2000,
    'grape': 3000
}

print(list(fruits.keys()))
print(list(fruits.values()))
print(list(fruits('banana')))
# Out:
# ['apple', 'banana', 'orange', 'grape']
# [1000, 1500, 2000, 3000]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 10
#       6 }
#       7
#       8 print(list(fruits.keys()))
#       9 print(list(fruits.values()))
# ---> 10 print(list(fruits('banana')))
#
# TypeError: 'dict' object is not callable

# %%
text = "python is great python is fun python is powerful"
a = text.split(" ")
a.count("python")
# Out:
# 3

# %%
dict = {
    "name" : "kim",
    "phone" : "010-1234-5678",
    "birth" : "09-02" 
}
dict.values()
list(dict.values())
# Out:
# ['kim', '010-1234-5678', '09-02']

# %%
school = {
    '1반': {
        '김철수': {'국어': 85, '영어': 90, '수학': 78},
        '이영희': {'국어': 92, '영어': 88, '수학': 95}
    },
    '2반': {
        '박민수': {'국어': 88, '영어': 85, '수학': 90},
        '최지영': {'국어': 95, '영어': 92, '수학': 88}
    }
}

print(school['1반']['김철수']['수학'])
sum(list(school['2반']['박민수'].values())) / 3
# Out:
# 78
# 87.66666666666667

# %%
school = [
        {'이름': '김철수', '국어': 85, '영어': 90, '수학': 78},
        {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95}, 
        {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
        {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
]
print(type(school[3]))
school[3]['국어']
# Out:
# <class 'dict'>
# 95

# %%
s1 = set("Hello")
print(s1)
s2 = set([1, 2, 3, 2, 1, 3, 4])
print(s2)
s3 = {}
print(type(s3))
# Out:
# {'o', 'e', 'H', 'l'}
# {1, 2, 3, 4}
# <class 'dict'>
