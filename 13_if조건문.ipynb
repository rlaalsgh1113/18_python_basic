# %%
# if 조건문 사용하기

# if 조건식 :
#     코드

x = 10
if x == 10 :
    print("10입니다.")
# Out:
# 10입니다.

# %%
# if 조건문을 사용할 때 주의할 점
x = 10
if x == 10 :
# Out:
#   Cell In[3], line 3
#     if x == 10 :
#                 ^
# _IncompleteInputError: incomplete input

# %%
# if 조건문에서 코드를 생략하기

x = 10
if x == 10 :
    pass

# %%
# if 조건문과 들여쓰기

x = 10
if x == 10 :
    print("x에 들어 있는 숫자는")
    print("10입니다.")
# Out:
# x에 들어 있는 숫자는
# 10입니다.

# %%
# 중첩 if 조건문 사용하기

x = 15
if x >= 10 :
    print("10이상입니다.")

    if x == 15 :
        print("15입니다.")

    if x == 20 :
        print("20입니다.")
# Out:
# 10이상입니다.
# 15입니다.

# %%
# 사용자가 입력한 값에 if 조건문 사용하기

x = int(input())

if x  == 10 :
    print("10입니다.")

if x == 20 :
    print("20입니다.")
# Out:
# 20입니다.

# %%
# 연습문제 13.6
# p.164

x = 5

if x != 10 :
    print("OK")
# Out:
# OK

# %%
# 심사문제 13.7

price = int(input())
coupon = input()

if coupon == "Cash3000" :
    print(price - 3000)

if coupon == "Cash5000" :
    print(price - 5000)
# Out:
# 67000
