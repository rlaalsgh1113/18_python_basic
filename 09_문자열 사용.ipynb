# %%
# 문자열 사용
hello = "hello world"
print(hello)
# Out:
# hello world

# %%
hello = "안녕하세요"
print(hello)
# Out:
# 안녕하세요

# %%
hello = '''hello, python'''
print(hello)
# Out:
# hello, python

# %%
python = """python programming"""
python
# Out:
# 'python programming'

# %%
# 여러 줄로 된 문자열 사용하기
hello = '''hello world!
안녕하세요.
python입니다'''  # 작은따옴표나 큰따옴표 3개를 써야 줄바꿈이 가능
print(hello)
# Out:
# hello world!
# 안녕하세요.
# python입니다

# %%
# 문자열 안에 작은따옴표나 큰따옴표 포함하기
s = "python isn't difficult"
print(s)
d = 'python isn\'t difficult'
print(d)
# Out:
# python isn't difficult
# python isn't difficult

# %%
s = 'he said "python is easy"'
print(s)
# Out:
# he said "python is easy"

# %%
single_quote = '''"안녕하세요."
'파이썬'입니다.'''
print(single_quote)
# Out:
# "안녕하세요."
# '파이썬'입니다.

# %%
# 연습문제 9.3
s = """python is a programming language that lets you work quickly
and
integrate systems more effectively"""

print(s)
# Out:
# python is a programming language that lets you work quickly
# and
# integrate systems more effectively

# %%
# 심사문제 9.4
s = """'python' is a \"programming language\"
tath lets you work quickly
and
integrate systems more effectively"""
print(s)
# Out:
# 'python' is a "programming language"
# tath lets you work quickly
# and
# integrate systems more effectively
